# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
import seaborn as sns
palette = 'muted'
sns.set_palette(palette); sns.set_color_codes(palette)

# %%
mu_params = [-1, 0, 1]
sd_params = [0.5, 1, 1.5]
x = np.linspace(-7, 7, 100)
x.shape
f, ax = plt.subplots(len(mu_params), len(sd_params), sharex=True, sharey=True)
for i in range(3):
    for j in range(3):
        mu = mu_params[i]
        sd = sd_params[j]
        y = stats.norm(mu, sd).pdf(x)

        ax[i,j].plot(x, y)
        ax[i,j].plot(0, 0, 
        label="$\\mu$ = {:3.2f}\n$\\sigma$ = {:3.2f}".format(mu, sd), alpha=0)
        ax[i,j].legend(fontsize=12)
ax[2,1].set_xlabel('$x$', fontsize=16)
ax[1,0].set_ylabel('$pdf(x)$', fontsize=16)
plt.tight_layout()
plt.show()
# plt.savefig('B04958_01_01.png', dpi=300, figsize=(5.5, 5.5))

# %% [markdown]
# This Python code is using the matplotlib library to create a grid of subplots and plot the probability density function (pdf) of a normal distribution with different parameters.
#
# The first line creates a grid of subplots with a number of rows equal to the length of [`mu_params`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22fsPath%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22path%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22scheme%22%3A%22vscode-notebook-cell%22%2C%22fragment%22%3A%22X12sZmlsZQ%3D%3D%22%7D%2C%7B%22line%22%3A0%2C%22character%22%3A0%7D%5D "/home/hung/Documents/make_color/AI/bayesian_analysis_with_python/1ed/Chapter 1/sample.ipynb") and a number of columns equal to the length of [`sd_params`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22fsPath%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22path%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22scheme%22%3A%22vscode-notebook-cell%22%2C%22fragment%22%3A%22X12sZmlsZQ%3D%3D%22%7D%2C%7B%22line%22%3A1%2C%22character%22%3A0%7D%5D "/home/hung/Documents/make_color/AI/bayesian_analysis_with_python/1ed/Chapter 1/sample.ipynb"). The [`sharex=True`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22path%22%3A%22%2Fhome%2Fhung%2F.local%2Fshare%2Fvirtualenvs%2Fstock_investing-VnnxBpBf%2Flib%2Fpython3.8%2Fsite-packages%2Fmatplotlib%2Fpyplot.py%22%2C%22scheme%22%3A%22file%22%7D%2C%7B%22line%22%3A1354%2C%22character%22%3A34%7D%5D "../../../../.local/share/virtualenvs/stock_investing-VnnxBpBf/lib/python3.8/site-packages/matplotlib/pyplot.py") and [`sharey=True`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22path%22%3A%22%2Fhome%2Fhung%2F.local%2Fshare%2Fvirtualenvs%2Fstock_investing-VnnxBpBf%2Flib%2Fpython3.8%2Fsite-packages%2Fmatplotlib%2Fpyplot.py%22%2C%22scheme%22%3A%22file%22%7D%2C%7B%22line%22%3A1354%2C%22character%22%3A48%7D%5D "../../../../.local/share/virtualenvs/stock_investing-VnnxBpBf/lib/python3.8/site-packages/matplotlib/pyplot.py") arguments mean that the x-axis and y-axis will be shared among all subplots.
#
# Then, two nested for loops are used to iterate over each subplot. For each subplot, the mean ([`mu`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22fsPath%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22path%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22scheme%22%3A%22vscode-notebook-cell%22%2C%22fragment%22%3A%22W1sZmlsZQ%3D%3D%22%7D%2C%7B%22line%22%3A3%2C%22character%22%3A8%7D%5D "/home/hung/Documents/make_color/AI/bayesian_analysis_with_python/1ed/Chapter 1/sample.ipynb")) and standard deviation ([`sd`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22fsPath%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22path%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22scheme%22%3A%22vscode-notebook-cell%22%2C%22fragment%22%3A%22W1sZmlsZQ%3D%3D%22%7D%2C%7B%22line%22%3A4%2C%22character%22%3A8%7D%5D "/home/hung/Documents/make_color/AI/bayesian_analysis_with_python/1ed/Chapter 1/sample.ipynb")) are taken from the [`mu_params`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22fsPath%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22path%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22scheme%22%3A%22vscode-notebook-cell%22%2C%22fragment%22%3A%22X12sZmlsZQ%3D%3D%22%7D%2C%7B%22line%22%3A0%2C%22character%22%3A0%7D%5D "/home/hung/Documents/make_color/AI/bayesian_analysis_with_python/1ed/Chapter 1/sample.ipynb") and [`sd_params`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22fsPath%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22path%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22scheme%22%3A%22vscode-notebook-cell%22%2C%22fragment%22%3A%22X12sZmlsZQ%3D%3D%22%7D%2C%7B%22line%22%3A1%2C%22character%22%3A0%7D%5D "/home/hung/Documents/make_color/AI/bayesian_analysis_with_python/1ed/Chapter 1/sample.ipynb") lists respectively. The [`stats.norm(mu, sd).pdf(x)`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22path%22%3A%22%2Fhome%2Fhung%2F.local%2Fshare%2Fvirtualenvs%2Fstock_investing-VnnxBpBf%2Flib%2Fpython3.8%2Fsite-packages%2Fscipy%2Fstats%2F__init__.py%22%2C%22scheme%22%3A%22file%22%7D%2C%7B%22line%22%3A0%2C%22character%22%3A0%7D%5D "../../../../.local/share/virtualenvs/stock_investing-VnnxBpBf/lib/python3.8/site-packages/scipy/stats/__init__.py") line calculates the pdf of a normal distribution with mean [`mu`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22fsPath%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22path%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22scheme%22%3A%22vscode-notebook-cell%22%2C%22fragment%22%3A%22W1sZmlsZQ%3D%3D%22%7D%2C%7B%22line%22%3A3%2C%22character%22%3A8%7D%5D "/home/hung/Documents/make_color/AI/bayesian_analysis_with_python/1ed/Chapter 1/sample.ipynb") and standard deviation [`sd`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22fsPath%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22path%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22scheme%22%3A%22vscode-notebook-cell%22%2C%22fragment%22%3A%22W1sZmlsZQ%3D%3D%22%7D%2C%7B%22line%22%3A4%2C%22character%22%3A8%7D%5D "/home/hung/Documents/make_color/AI/bayesian_analysis_with_python/1ed/Chapter 1/sample.ipynb") at the points specified by [`x`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22fsPath%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22path%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22scheme%22%3A%22vscode-notebook-cell%22%2C%22fragment%22%3A%22X13sZmlsZQ%3D%3D%22%7D%2C%7B%22line%22%3A0%2C%22character%22%3A0%7D%5D "/home/hung/Documents/make_color/AI/bayesian_analysis_with_python/1ed/Chapter 1/sample.ipynb").
#
# The next two lines plot the pdf on the subplot and add a label that includes the mean and standard deviation. The `alpha=0` argument means that this label line will be completely transparent.
#
# The [`ax[i,j].legend(fontsize=12)`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22fsPath%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22path%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22scheme%22%3A%22vscode-notebook-cell%22%2C%22fragment%22%3A%22W1sZmlsZQ%3D%3D%22%7D%2C%7B%22line%22%3A0%2C%22character%22%3A3%7D%5D "/home/hung/Documents/make_color/AI/bayesian_analysis_with_python/1ed/Chapter 1/sample.ipynb") line adds a legend to the subplot, and the [`ax[2,1].set_xlabel('$x$', fontsize=16)`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22fsPath%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22path%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22scheme%22%3A%22vscode-notebook-cell%22%2C%22fragment%22%3A%22W1sZmlsZQ%3D%3D%22%7D%2C%7B%22line%22%3A0%2C%22character%22%3A3%7D%5D "/home/hung/Documents/make_color/AI/bayesian_analysis_with_python/1ed/Chapter 1/sample.ipynb") and [`ax[1,0].set_ylabel('$pdf(x)$', fontsize=16)`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22fsPath%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22path%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22scheme%22%3A%22vscode-notebook-cell%22%2C%22fragment%22%3A%22W1sZmlsZQ%3D%3D%22%7D%2C%7B%22line%22%3A0%2C%22character%22%3A3%7D%5D "/home/hung/Documents/make_color/AI/bayesian_analysis_with_python/1ed/Chapter 1/sample.ipynb") lines set the labels for the x-axis and y-axis respectively.
#
# Finally, [`plt.tight_layout()`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22path%22%3A%22%2Fhome%2Fhung%2F.local%2Fshare%2Fvirtualenvs%2Fstock_investing-VnnxBpBf%2Flib%2Fpython3.8%2Fsite-packages%2Fmatplotlib%2Fpyplot.py%22%2C%22scheme%22%3A%22file%22%7D%2C%7B%22line%22%3A0%2C%22character%22%3A0%7D%5D "../../../../.local/share/virtualenvs/stock_investing-VnnxBpBf/lib/python3.8/site-packages/matplotlib/pyplot.py") adjusts the subplot parameters so that the subplots fit into the figure area, [`plt.show()`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22path%22%3A%22%2Fhome%2Fhung%2F.local%2Fshare%2Fvirtualenvs%2Fstock_investing-VnnxBpBf%2Flib%2Fpython3.8%2Fsite-packages%2Fmatplotlib%2Fpyplot.py%22%2C%22scheme%22%3A%22file%22%7D%2C%7B%22line%22%3A0%2C%22character%22%3A0%7D%5D "../../../../.local/share/virtualenvs/stock_investing-VnnxBpBf/lib/python3.8/site-packages/matplotlib/pyplot.py") displays the figure, and the last line (which is commented out) would save the figure as a png file if it were uncommented.

# %%
data = np.genfromtxt('mauna_loa_CO2.csv', delimiter=',')
data.shape
# Out:
# (468, 2)

# %%
plt.plot(data[:,0], data[:,1])
plt.xlabel('$year$', fontsize=16)
plt.ylabel('$CO_2 (ppmv)$', fontsize=16)
plt.show()
# plt.savefig('B04958_01_02.png', dpi=300, figsize=(5.5, 5.5))

# %%
n_params = [1, 2, 4]
p_params = [0.25, 0.5, 0.75]
x = np.arange(0, max(n_params)+1)
f, ax = plt.subplots(len(n_params), len(p_params), sharex=True, sharey=True)
for i in range(3):
    for j in range(3):
        n = n_params[i]
        p = p_params[j]
        y = stats.binom(n=n, p=p).pmf(x)
        ax[i,j].vlines(x, 0, y, colors='b', lw=5)
        ax[i,j].set_ylim(0, 1)
        ax[i,j].plot(0, 0, label="n = {:3.2f}\np = {:3.2f}".format(n, p), alpha=0)
        ax[i,j].legend(fontsize=12)
ax[2,1].set_xlabel('$\\theta$', fontsize=14)
ax[1,0].set_ylabel('$p(y|\\theta)$', fontsize=14)
ax[0,0].set_xticks(x)
plt.show()
# plt.savefig('B04958_01_03.png', dpi=300, figsize=(5.5, 5.5))

# %% [markdown]
# This Python code is using the matplotlib and scipy libraries to create a grid of subplots, each of which shows the probability mass function (PMF) of a binomial distribution with different parameters.
#
# The binomial distribution is a discrete probability distribution of the number of successes in a sequence of n independent experiments. These parameters [`n`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22fsPath%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22path%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22scheme%22%3A%22vscode-notebook-cell%22%2C%22fragment%22%3A%22W3sZmlsZQ%3D%3D%22%7D%2C%7B%22line%22%3A6%2C%22character%22%3A8%7D%5D "/home/hung/Documents/make_color/AI/bayesian_analysis_with_python/1ed/Chapter 1/sample.ipynb") and [`p`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22fsPath%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22path%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22scheme%22%3A%22vscode-notebook-cell%22%2C%22fragment%22%3A%22W3sZmlsZQ%3D%3D%22%7D%2C%7B%22line%22%3A7%2C%22character%22%3A8%7D%5D "/home/hung/Documents/make_color/AI/bayesian_analysis_with_python/1ed/Chapter 1/sample.ipynb") are defined in the lists [`n_params`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22fsPath%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22path%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22scheme%22%3A%22vscode-notebook-cell%22%2C%22fragment%22%3A%22W3sZmlsZQ%3D%3D%22%7D%2C%7B%22line%22%3A0%2C%22character%22%3A0%7D%5D "/home/hung/Documents/make_color/AI/bayesian_analysis_with_python/1ed/Chapter 1/sample.ipynb") and [`p_params`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22fsPath%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22path%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22scheme%22%3A%22vscode-notebook-cell%22%2C%22fragment%22%3A%22W3sZmlsZQ%3D%3D%22%7D%2C%7B%22line%22%3A1%2C%22character%22%3A0%7D%5D "/home/hung/Documents/make_color/AI/bayesian_analysis_with_python/1ed/Chapter 1/sample.ipynb") respectively. The [`x`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22fsPath%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22path%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22scheme%22%3A%22vscode-notebook-cell%22%2C%22fragment%22%3A%22W3sZmlsZQ%3D%3D%22%7D%2C%7B%22line%22%3A2%2C%22character%22%3A0%7D%5D "/home/hung/Documents/make_color/AI/bayesian_analysis_with_python/1ed/Chapter 1/sample.ipynb") variable is an array of numbers from 0 to the maximum value in [`n_params`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22fsPath%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22path%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22scheme%22%3A%22vscode-notebook-cell%22%2C%22fragment%22%3A%22W3sZmlsZQ%3D%3D%22%7D%2C%7B%22line%22%3A0%2C%22character%22%3A0%7D%5D "/home/hung/Documents/make_color/AI/bayesian_analysis_with_python/1ed/Chapter 1/sample.ipynb") + 1.
#
# The [`f, ax = plt.subplots(len(n_params), len(p_params), sharex=True, sharey=True)`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22fsPath%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22path%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22scheme%22%3A%22vscode-notebook-cell%22%2C%22fragment%22%3A%22W3sZmlsZQ%3D%3D%22%7D%2C%7B%22line%22%3A3%2C%22character%22%3A0%7D%5D "/home/hung/Documents/make_color/AI/bayesian_analysis_with_python/1ed/Chapter 1/sample.ipynb") line creates a grid of subplots with the number of rows equal to the length of [`n_params`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22fsPath%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22path%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22scheme%22%3A%22vscode-notebook-cell%22%2C%22fragment%22%3A%22W3sZmlsZQ%3D%3D%22%7D%2C%7B%22line%22%3A0%2C%22character%22%3A0%7D%5D "/home/hung/Documents/make_color/AI/bayesian_analysis_with_python/1ed/Chapter 1/sample.ipynb") and the number of columns equal to the length of [`p_params`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22fsPath%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22path%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22scheme%22%3A%22vscode-notebook-cell%22%2C%22fragment%22%3A%22W3sZmlsZQ%3D%3D%22%7D%2C%7B%22line%22%3A1%2C%22character%22%3A0%7D%5D "/home/hung/Documents/make_color/AI/bayesian_analysis_with_python/1ed/Chapter 1/sample.ipynb"). The [`sharex`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22path%22%3A%22%2Fhome%2Fhung%2F.local%2Fshare%2Fvirtualenvs%2Fstock_investing-VnnxBpBf%2Flib%2Fpython3.8%2Fsite-packages%2Fmatplotlib%2Fpyplot.py%22%2C%22scheme%22%3A%22file%22%7D%2C%7B%22line%22%3A1354%2C%22character%22%3A34%7D%5D "../../../../.local/share/virtualenvs/stock_investing-VnnxBpBf/lib/python3.8/site-packages/matplotlib/pyplot.py") and [`sharey`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22path%22%3A%22%2Fhome%2Fhung%2F.local%2Fshare%2Fvirtualenvs%2Fstock_investing-VnnxBpBf%2Flib%2Fpython3.8%2Fsite-packages%2Fmatplotlib%2Fpyplot.py%22%2C%22scheme%22%3A%22file%22%7D%2C%7B%22line%22%3A1354%2C%22character%22%3A48%7D%5D "../../../../.local/share/virtualenvs/stock_investing-VnnxBpBf/lib/python3.8/site-packages/matplotlib/pyplot.py") parameters ensure that the subplots share the same x and y axis.
#
# The nested for loop iterates over each combination of [`n`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22fsPath%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22path%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22scheme%22%3A%22vscode-notebook-cell%22%2C%22fragment%22%3A%22W3sZmlsZQ%3D%3D%22%7D%2C%7B%22line%22%3A6%2C%22character%22%3A8%7D%5D "/home/hung/Documents/make_color/AI/bayesian_analysis_with_python/1ed/Chapter 1/sample.ipynb") and [`p`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22fsPath%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22path%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22scheme%22%3A%22vscode-notebook-cell%22%2C%22fragment%22%3A%22W3sZmlsZQ%3D%3D%22%7D%2C%7B%22line%22%3A7%2C%22character%22%3A8%7D%5D "/home/hung/Documents/make_color/AI/bayesian_analysis_with_python/1ed/Chapter 1/sample.ipynb") parameters. For each combination, it calculates the PMF of the binomial distribution using [`stats.binom(n=n, p=p).pmf(x)`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22path%22%3A%22%2Fhome%2Fhung%2F.local%2Fshare%2Fvirtualenvs%2Fstock_investing-VnnxBpBf%2Flib%2Fpython3.8%2Fsite-packages%2Fscipy%2Fstats%2F__init__.py%22%2C%22scheme%22%3A%22file%22%7D%2C%7B%22line%22%3A0%2C%22character%22%3A0%7D%5D "../../../../.local/share/virtualenvs/stock_investing-VnnxBpBf/lib/python3.8/site-packages/scipy/stats/__init__.py"). This PMF is then plotted on the corresponding subplot using vertical lines with [`ax[i,j].vlines(x, 0, y, colors='b', lw=5)`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22fsPath%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22path%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22scheme%22%3A%22vscode-notebook-cell%22%2C%22fragment%22%3A%22W3sZmlsZQ%3D%3D%22%7D%2C%7B%22line%22%3A3%2C%22character%22%3A3%7D%5D "/home/hung/Documents/make_color/AI/bayesian_analysis_with_python/1ed/Chapter 1/sample.ipynb"). The `set_ylim` function is used to set the limits of the y-axis to be between 0 and 1.
#
# The [`ax[i,j].plot(0, 0, label="n = {:3.2f}\np = {:3.2f}".format(n, p), alpha=0)`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22fsPath%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22path%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22scheme%22%3A%22vscode-notebook-cell%22%2C%22fragment%22%3A%22W3sZmlsZQ%3D%3D%22%7D%2C%7B%22line%22%3A3%2C%22character%22%3A3%7D%5D "/home/hung/Documents/make_color/AI/bayesian_analysis_with_python/1ed/Chapter 1/sample.ipynb") line is a clever way to add a legend to the plot that shows the [`n`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22fsPath%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22path%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22scheme%22%3A%22vscode-notebook-cell%22%2C%22fragment%22%3A%22W3sZmlsZQ%3D%3D%22%7D%2C%7B%22line%22%3A6%2C%22character%22%3A8%7D%5D "/home/hung/Documents/make_color/AI/bayesian_analysis_with_python/1ed/Chapter 1/sample.ipynb") and [`p`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22fsPath%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22path%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22scheme%22%3A%22vscode-notebook-cell%22%2C%22fragment%22%3A%22W3sZmlsZQ%3D%3D%22%7D%2C%7B%22line%22%3A7%2C%22character%22%3A8%7D%5D "/home/hung/Documents/make_color/AI/bayesian_analysis_with_python/1ed/Chapter 1/sample.ipynb") parameters for that subplot. The `alpha=0` makes the line itself invisible.
#
# Finally, the [`ax[2,1].set_xlabel('$\\theta$', fontsize=14)`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22fsPath%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22path%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22scheme%22%3A%22vscode-notebook-cell%22%2C%22fragment%22%3A%22W3sZmlsZQ%3D%3D%22%7D%2C%7B%22line%22%3A3%2C%22character%22%3A3%7D%5D "/home/hung/Documents/make_color/AI/bayesian_analysis_with_python/1ed/Chapter 1/sample.ipynb"), [`ax[1,0].set_ylabel('$p(y|\\theta)$', fontsize=14)`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22fsPath%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22path%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22scheme%22%3A%22vscode-notebook-cell%22%2C%22fragment%22%3A%22W3sZmlsZQ%3D%3D%22%7D%2C%7B%22line%22%3A3%2C%22character%22%3A3%7D%5D "/home/hung/Documents/make_color/AI/bayesian_analysis_with_python/1ed/Chapter 1/sample.ipynb"), and [`ax[0,0].set_xticks(x)`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22fsPath%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22path%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22scheme%22%3A%22vscode-notebook-cell%22%2C%22fragment%22%3A%22W3sZmlsZQ%3D%3D%22%7D%2C%7B%22line%22%3A3%2C%22character%22%3A3%7D%5D "/home/hung/Documents/make_color/AI/bayesian_analysis_with_python/1ed/Chapter 1/sample.ipynb") lines are used to set the labels for the x and y axes and the x-ticks for the first subplot.
#
# The [`plt.show()`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22path%22%3A%22%2Fhome%2Fhung%2F.local%2Fshare%2Fvirtualenvs%2Fstock_investing-VnnxBpBf%2Flib%2Fpython3.8%2Fsite-packages%2Fmatplotlib%2Fpyplot.py%22%2C%22scheme%22%3A%22file%22%7D%2C%7B%22line%22%3A0%2C%22character%22%3A0%7D%5D "../../../../.local/share/virtualenvs/stock_investing-VnnxBpBf/lib/python3.8/site-packages/matplotlib/pyplot.py") line displays the plot. The commented out line [`# plt.savefig('B04958_01_03.png', dpi=300, figsize=(5.5, 5.5))`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22path%22%3A%22%2Fhome%2Fhung%2F.local%2Fshare%2Fvirtualenvs%2Fstock_investing-VnnxBpBf%2Flib%2Fpython3.8%2Fsite-packages%2Fmatplotlib%2Fpyplot.py%22%2C%22scheme%22%3A%22file%22%7D%2C%7B%22line%22%3A0%2C%22character%22%3A0%7D%5D "../../../../.local/share/virtualenvs/stock_investing-VnnxBpBf/lib/python3.8/site-packages/matplotlib/pyplot.py") can be used to save the figure to a file instead of displaying it.

# %%
params = [0.5, 1, 2, 3]
x = np.linspace(0, 1, 100)
f, ax = plt.subplots(len(params), len(params), sharex=True, 
  sharey=True)
for i in range(4):
    for j in range(4):
        a = params[i]
        b = params[j]
        y = stats.beta(a, b).pdf(x)
        ax[i,j].plot(x, y)
        ax[i,j].plot(0, 0, label="$\\alpha$ = {:3.2f}\n$\\beta$ = {:3.2f}".format(a, b), alpha=0)
        ax[i,j].legend(fontsize=12)
ax[3,0].set_xlabel('$\\theta$', fontsize=14)
ax[0,0].set_ylabel('$p(\\theta)$', fontsize=14)
plt.show()
# plt.savefig('B04958_01_04.png', dpi=300, figsize=(5.5, 5.5))

# %% [markdown]
# The provided Python code is used to generate a grid of plots that visualize the Probability Density Function (PDF) of the Beta distribution for different parameters. The Beta distribution is a continuous probability distribution having two parameters. It is often used in Bayesian statistics, to describe statistical distributions of random variables lying between 0 and 1.
#
# The code starts by defining a list of parameters [`params = [0.5, 1, 2, 3]`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22fsPath%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22path%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22scheme%22%3A%22vscode-notebook-cell%22%2C%22fragment%22%3A%22W4sZmlsZQ%3D%3D%22%7D%2C%7B%22line%22%3A0%2C%22character%22%3A0%7D%5D "/home/hung/Documents/make_color/AI/bayesian_analysis_with_python/1ed/Chapter 1/sample.ipynb"). These parameters will be used as the alpha and beta parameters of the Beta distribution.
#
# Next, [`x = np.linspace(0, 1, 100)`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22fsPath%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22path%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22scheme%22%3A%22vscode-notebook-cell%22%2C%22fragment%22%3A%22W4sZmlsZQ%3D%3D%22%7D%2C%7B%22line%22%3A1%2C%22character%22%3A0%7D%5D "/home/hung/Documents/make_color/AI/bayesian_analysis_with_python/1ed/Chapter 1/sample.ipynb") generates an array of 100 evenly spaced values between 0 and 1. This array will be used as the input to the Beta distribution's PDF.
#
# The [`f, ax = plt.subplots(len(params), len(params), sharex=True, sharey=True)`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22fsPath%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22path%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22scheme%22%3A%22vscode-notebook-cell%22%2C%22fragment%22%3A%22W4sZmlsZQ%3D%3D%22%7D%2C%7B%22line%22%3A2%2C%22character%22%3A0%7D%5D "/home/hung/Documents/make_color/AI/bayesian_analysis_with_python/1ed/Chapter 1/sample.ipynb") line creates a grid of subplots with the number of rows and columns equal to the number of parameters. The [`sharex=True`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22path%22%3A%22%2Fhome%2Fhung%2F.local%2Fshare%2Fvirtualenvs%2Fstock_investing-VnnxBpBf%2Flib%2Fpython3.8%2Fsite-packages%2Fmatplotlib%2Fpyplot.py%22%2C%22scheme%22%3A%22file%22%7D%2C%7B%22line%22%3A1354%2C%22character%22%3A34%7D%5D "../../../../.local/share/virtualenvs/stock_investing-VnnxBpBf/lib/python3.8/site-packages/matplotlib/pyplot.py") and [`sharey=True`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22path%22%3A%22%2Fhome%2Fhung%2F.local%2Fshare%2Fvirtualenvs%2Fstock_investing-VnnxBpBf%2Flib%2Fpython3.8%2Fsite-packages%2Fmatplotlib%2Fpyplot.py%22%2C%22scheme%22%3A%22file%22%7D%2C%7B%22line%22%3A1354%2C%22character%22%3A48%7D%5D "../../../../.local/share/virtualenvs/stock_investing-VnnxBpBf/lib/python3.8/site-packages/matplotlib/pyplot.py") arguments mean that the subplots will share the same x and y axis.
#
# The nested for loop iterates over all combinations of parameters. For each combination, it calculates the PDF of the Beta distribution using [`y = stats.beta(a, b).pdf(x)`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22fsPath%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22path%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22scheme%22%3A%22vscode-notebook-cell%22%2C%22fragment%22%3A%22W4sZmlsZQ%3D%3D%22%7D%2C%7B%22line%22%3A8%2C%22character%22%3A8%7D%5D "/home/hung/Documents/make_color/AI/bayesian_analysis_with_python/1ed/Chapter 1/sample.ipynb"), and then plots the result on the corresponding subplot using [`ax[i,j].plot(x, y)`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22fsPath%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22path%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22scheme%22%3A%22vscode-notebook-cell%22%2C%22fragment%22%3A%22W4sZmlsZQ%3D%3D%22%7D%2C%7B%22line%22%3A2%2C%22character%22%3A3%7D%5D "/home/hung/Documents/make_color/AI/bayesian_analysis_with_python/1ed/Chapter 1/sample.ipynb").
#
# The line [`ax[i,j].plot(0, 0, label="$\\alpha$ = {:3.2f}\n$\\beta$ = {:3.2f}".format(a, b), alpha=0)`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22fsPath%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22path%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22scheme%22%3A%22vscode-notebook-cell%22%2C%22fragment%22%3A%22W4sZmlsZQ%3D%3D%22%7D%2C%7B%22line%22%3A2%2C%22character%22%3A3%7D%5D "/home/hung/Documents/make_color/AI/bayesian_analysis_with_python/1ed/Chapter 1/sample.ipynb") is used to add a legend to each subplot that shows the alpha and beta parameters used for that plot. The `alpha=0` argument means that this line itself (a point at (0,0)) is invisible.
#
# Finally, [`ax[3,0].set_xlabel('$\\theta$', fontsize=14)`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22fsPath%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22path%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22scheme%22%3A%22vscode-notebook-cell%22%2C%22fragment%22%3A%22W4sZmlsZQ%3D%3D%22%7D%2C%7B%22line%22%3A2%2C%22character%22%3A3%7D%5D "/home/hung/Documents/make_color/AI/bayesian_analysis_with_python/1ed/Chapter 1/sample.ipynb") and [`ax[0,0].set_ylabel('$p(\\theta)$', fontsize=14)`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22fsPath%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22path%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22scheme%22%3A%22vscode-notebook-cell%22%2C%22fragment%22%3A%22W4sZmlsZQ%3D%3D%22%7D%2C%7B%22line%22%3A2%2C%22character%22%3A3%7D%5D "/home/hung/Documents/make_color/AI/bayesian_analysis_with_python/1ed/Chapter 1/sample.ipynb") are used to set the labels for the x and y axes, and [`plt.show()`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22path%22%3A%22%2Fhome%2Fhung%2F.local%2Fshare%2Fvirtualenvs%2Fstock_investing-VnnxBpBf%2Flib%2Fpython3.8%2Fsite-packages%2Fmatplotlib%2Fpyplot.py%22%2C%22scheme%22%3A%22file%22%7D%2C%7B%22line%22%3A0%2C%22character%22%3A0%7D%5D "../../../../.local/share/virtualenvs/stock_investing-VnnxBpBf/lib/python3.8/site-packages/matplotlib/pyplot.py") is used to display the plot.
#
# The commented out line [`# plt.savefig('B04958_01_04.png', dpi=300, figsize=(5.5, 5.5))`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22path%22%3A%22%2Fhome%2Fhung%2F.local%2Fshare%2Fvirtualenvs%2Fstock_investing-VnnxBpBf%2Flib%2Fpython3.8%2Fsite-packages%2Fmatplotlib%2Fpyplot.py%22%2C%22scheme%22%3A%22file%22%7D%2C%7B%22line%22%3A0%2C%22character%22%3A0%7D%5D "../../../../.local/share/virtualenvs/stock_investing-VnnxBpBf/lib/python3.8/site-packages/matplotlib/pyplot.py") can be used to save the figure to a file instead of displaying it.
#
# The [`linspace`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22path%22%3A%22%2Fhome%2Fhung%2F.local%2Fshare%2Fvirtualenvs%2Fstock_investing-VnnxBpBf%2Flib%2Fpython3.8%2Fsite-packages%2Fnumpy%2Fcore%2Ffunction_base.py%22%2C%22scheme%22%3A%22file%22%7D%2C%7B%22line%22%3A23%2C%22character%22%3A4%7D%5D "../../../../.local/share/virtualenvs/stock_investing-VnnxBpBf/lib/python3.8/site-packages/numpy/core/function_base.py") function is a NumPy function that returns evenly spaced numbers over a specified interval. It takes in the start and stop values of the sequence, and the number of samples to generate. The [`range`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22path%22%3A%22%2Fhome%2Fhung%2F.vscode%2Fextensions%2Fms-python.vscode-pylance-2024.5.1%2Fdist%2Ftypeshed-fallback%2Fstdlib%2Fbuiltins.pyi%22%2C%22scheme%22%3A%22file%22%7D%2C%7B%22line%22%3A1176%2C%22character%22%3A6%7D%5D "../../../../.vscode/extensions/ms-python.vscode-pylance-2024.5.1/dist/typeshed-fallback/stdlib/builtins.pyi") class is a built-in Python class that represents an immutable sequence of numbers and is commonly used for looping a specific number of times in for loops.

# %%
theta_real = 0.35
trials = [0, 1, 2, 3, 4, 8, 16, 32, 50, 150]
data = [0, 1, 1, 1, 1, 4, 6, 9, 13, 48]

beta_params = [(1, 1), (0.5, 0.5), (20, 20)]
dist = stats.beta
x = np.linspace(0, 1, 100)

for idx, N in enumerate(trials):
    if idx == 0:
        plt.subplot(4,3, 2)
    else:
        plt.subplot(4,3, idx+3)
    y = data[idx]
    for (a_prior, b_prior), c in zip(beta_params, ('b', 'r', 'g')):
        p_theta_given_y = dist.pdf(x, a_prior + y, b_prior + N - y)
        plt.plot(x, p_theta_given_y, c)
        plt.fill_between(x, 0, p_theta_given_y, color=c, alpha=0.6)

    plt.axvline(theta_real, ymax=0.3, color='k')
    plt.plot(0, 0, label="{:d} experiments\n{:d} heads".format(N, y), alpha=0)
    plt.xlim(0,1)
    plt.ylim(0,12)
    plt.xlabel(r"$\theta$") 
    plt.legend()
    plt.gca().axes.get_yaxis().set_visible(False)
plt.tight_layout()
plt.show()
# plt.savefig('B04958_01_05.png', dpi=300, figsize=(5.5, 5.5))

# %% [markdown]
# This Python code is using the matplotlib and scipy libraries to create a series of plots that visualize the probability density function (PDF) of a Beta distribution. The Beta distribution is a continuous probability distribution that has two parameters. It is often used in Bayesian statistics, as it is the conjugate prior probability distribution for the Bernoulli, binomial, negative binomial and geometric distributions.
#
# The code starts by defining some constants and parameters for the Beta distribution. [`theta_real`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22fsPath%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22path%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22scheme%22%3A%22vscode-notebook-cell%22%2C%22fragment%22%3A%22W5sZmlsZQ%3D%3D%22%7D%2C%7B%22line%22%3A0%2C%22character%22%3A0%7D%5D "/home/hung/Documents/make_color/AI/bayesian_analysis_with_python/1ed/Chapter 1/sample.ipynb") is the true value of the parameter theta, [`trials`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22fsPath%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22path%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22scheme%22%3A%22vscode-notebook-cell%22%2C%22fragment%22%3A%22W5sZmlsZQ%3D%3D%22%7D%2C%7B%22line%22%3A1%2C%22character%22%3A0%7D%5D "/home/hung/Documents/make_color/AI/bayesian_analysis_with_python/1ed/Chapter 1/sample.ipynb") is a list of the number of trials for each experiment, and data is the number of successful outcomes for each experiment. `beta_params` is a list of tuples, where each tuple represents the parameters of a Beta distribution. `dist` is set to the Beta distribution function from the scipy.stats module, and `x` is a numpy array of 100 evenly spaced numbers between 0 and 1.
#
# The code then enters a loop over the [`trials`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22fsPath%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22path%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22scheme%22%3A%22vscode-notebook-cell%22%2C%22fragment%22%3A%22W5sZmlsZQ%3D%3D%22%7D%2C%7B%22line%22%3A1%2C%22character%22%3A0%7D%5D "/home/hung/Documents/make_color/AI/bayesian_analysis_with_python/1ed/Chapter 1/sample.ipynb") list. For each trial, it creates a subplot in a 4x3 grid of plots. The first subplot is placed at position 2, and the rest are placed at positions 3 and onwards. The number of successes [`y`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22fsPath%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22path%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22scheme%22%3A%22vscode-notebook-cell%22%2C%22fragment%22%3A%22W5sZmlsZQ%3D%3D%22%7D%2C%7B%22line%22%3A13%2C%22character%22%3A4%7D%5D "/home/hung/Documents/make_color/AI/bayesian_analysis_with_python/1ed/Chapter 1/sample.ipynb") for the current trial is retrieved from the data list.
#
# Next, the code enters a nested loop over the [`beta_params`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22fsPath%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22path%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22scheme%22%3A%22vscode-notebook-cell%22%2C%22fragment%22%3A%22W5sZmlsZQ%3D%3D%22%7D%2C%7B%22line%22%3A4%2C%22character%22%3A0%7D%5D "/home/hung/Documents/make_color/AI/bayesian_analysis_with_python/1ed/Chapter 1/sample.ipynb") list and a list of color codes. For each Beta distribution parameter and color code, it calculates the PDF of the Beta distribution at each point in [`x`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22fsPath%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22path%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22scheme%22%3A%22vscode-notebook-cell%22%2C%22fragment%22%3A%22W5sZmlsZQ%3D%3D%22%7D%2C%7B%22line%22%3A6%2C%22character%22%3A0%7D%5D "/home/hung/Documents/make_color/AI/bayesian_analysis_with_python/1ed/Chapter 1/sample.ipynb"), using the current number of successes and failures as the parameters. It then plots the PDF and fills the area under the curve with the corresponding color.
#
# After plotting the PDFs, the code adds a vertical line at the true value of theta, adds a legend that shows the number of experiments and successes, and sets the x and y limits of the plot. It also hides the y-axis.
#
# Finally, after all subplots have been created, the code adjusts the layout to fit everything nicely and displays the plot. There's also a commented out line that can be used to save the plot as a PNG image.

# %%
def naive_hpd(post):
    sns.kdeplot(post)
    HPD = np.percentile(post, [2.5, 97.5])
    plt.plot(HPD, [0, 0], label='HPD {:.2f} {:.2f}'.format(*HPD), 
      linewidth=8, color='k')
    plt.legend(fontsize=16);
    plt.xlabel(r"$\theta$", fontsize=14)
    plt.gca().axes.get_yaxis().set_ticks([])

    
np.random.seed(1)
post = stats.beta.rvs(5, 11, size=1000)
naive_hpd(post)
plt.xlim(0, 1)
plt.show()
# plt.savefig('B04958_01_07.png', dpi=300, figsize=(5.5, 5.5))

# %% [markdown]
# The provided Python code is used to generate a plot of a Kernel Density Estimate (KDE) and the Highest Posterior Density (HPD) interval for a set of data. The data is generated using a beta distribution.
#
# The function [`naive_hpd(post)`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22fsPath%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22path%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22scheme%22%3A%22vscode-notebook-cell%22%2C%22fragment%22%3A%22W6sZmlsZQ%3D%3D%22%7D%2C%7B%22line%22%3A0%2C%22character%22%3A4%7D%5D "/home/hung/Documents/make_color/AI/bayesian_analysis_with_python/1ed/Chapter 1/sample.ipynb") takes a list or array-like object [`post`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22fsPath%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22path%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22scheme%22%3A%22vscode-notebook-cell%22%2C%22fragment%22%3A%22W6sZmlsZQ%3D%3D%22%7D%2C%7B%22line%22%3A0%2C%22character%22%3A14%7D%5D "/home/hung/Documents/make_color/AI/bayesian_analysis_with_python/1ed/Chapter 1/sample.ipynb") as an argument. This function first plots a KDE of [`post`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22fsPath%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22path%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22scheme%22%3A%22vscode-notebook-cell%22%2C%22fragment%22%3A%22W6sZmlsZQ%3D%3D%22%7D%2C%7B%22line%22%3A0%2C%22character%22%3A14%7D%5D "/home/hung/Documents/make_color/AI/bayesian_analysis_with_python/1ed/Chapter 1/sample.ipynb") using the [`sns.kdeplot(post)`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22path%22%3A%22%2Fhome%2Fhung%2F.local%2Fshare%2Fvirtualenvs%2Fstock_investing-VnnxBpBf%2Flib%2Fpython3.8%2Fsite-packages%2Fseaborn%2F__init__.py%22%2C%22scheme%22%3A%22file%22%7D%2C%7B%22line%22%3A0%2C%22character%22%3A0%7D%5D "../../../../.local/share/virtualenvs/stock_investing-VnnxBpBf/lib/python3.8/site-packages/seaborn/__init__.py") function from the seaborn library.
#
# Next, it calculates the 2.5th and 97.5th percentiles of [`post`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22fsPath%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22path%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22scheme%22%3A%22vscode-notebook-cell%22%2C%22fragment%22%3A%22W6sZmlsZQ%3D%3D%22%7D%2C%7B%22line%22%3A0%2C%22character%22%3A14%7D%5D "/home/hung/Documents/make_color/AI/bayesian_analysis_with_python/1ed/Chapter 1/sample.ipynb") using the [`np.percentile(post, [2.5, 97.5])`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22path%22%3A%22%2Fhome%2Fhung%2F.local%2Fshare%2Fvirtualenvs%2Fstock_investing-VnnxBpBf%2Flib%2Fpython3.8%2Fsite-packages%2Fnumpy%2F__init__.py%22%2C%22scheme%22%3A%22file%22%7D%2C%7B%22line%22%3A0%2C%22character%22%3A0%7D%5D "../../../../.local/share/virtualenvs/stock_investing-VnnxBpBf/lib/python3.8/site-packages/numpy/__init__.py") function from numpy, which effectively gives the HPD interval. This interval is then plotted on the same graph as a horizontal line using [`plt.plot(HPD, [0, 0], label='HPD {:.2f} {:.2f}'.format(*HPD), linewidth=8, color='k')`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22path%22%3A%22%2Fhome%2Fhung%2F.local%2Fshare%2Fvirtualenvs%2Fstock_investing-VnnxBpBf%2Flib%2Fpython3.8%2Fsite-packages%2Fmatplotlib%2Fpyplot.py%22%2C%22scheme%22%3A%22file%22%7D%2C%7B%22line%22%3A0%2C%22character%22%3A0%7D%5D "../../../../.local/share/virtualenvs/stock_investing-VnnxBpBf/lib/python3.8/site-packages/matplotlib/pyplot.py").
#
# The `label` argument in [`plt.plot`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22path%22%3A%22%2Fhome%2Fhung%2F.local%2Fshare%2Fvirtualenvs%2Fstock_investing-VnnxBpBf%2Flib%2Fpython3.8%2Fsite-packages%2Fmatplotlib%2Fpyplot.py%22%2C%22scheme%22%3A%22file%22%7D%2C%7B%22line%22%3A0%2C%22character%22%3A0%7D%5D "../../../../.local/share/virtualenvs/stock_investing-VnnxBpBf/lib/python3.8/site-packages/matplotlib/pyplot.py") is used to create a label for the line that shows the HPD interval values. The `linewidth` and `color` arguments are used to set the width and color of the line, respectively.
#
# The [`plt.legend(fontsize=16)`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22path%22%3A%22%2Fhome%2Fhung%2F.local%2Fshare%2Fvirtualenvs%2Fstock_investing-VnnxBpBf%2Flib%2Fpython3.8%2Fsite-packages%2Fmatplotlib%2Fpyplot.py%22%2C%22scheme%22%3A%22file%22%7D%2C%7B%22line%22%3A0%2C%22character%22%3A0%7D%5D "../../../../.local/share/virtualenvs/stock_investing-VnnxBpBf/lib/python3.8/site-packages/matplotlib/pyplot.py") function is used to display the legend on the plot, and [`plt.xlabel(r"$\theta$", fontsize=14)`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22path%22%3A%22%2Fhome%2Fhung%2F.local%2Fshare%2Fvirtualenvs%2Fstock_investing-VnnxBpBf%2Flib%2Fpython3.8%2Fsite-packages%2Fmatplotlib%2Fpyplot.py%22%2C%22scheme%22%3A%22file%22%7D%2C%7B%22line%22%3A0%2C%22character%22%3A0%7D%5D "../../../../.local/share/virtualenvs/stock_investing-VnnxBpBf/lib/python3.8/site-packages/matplotlib/pyplot.py") is used to set the label for the x-axis. The y-axis ticks are removed using [`plt.gca().axes.get_yaxis().set_ticks([])`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22path%22%3A%22%2Fhome%2Fhung%2F.local%2Fshare%2Fvirtualenvs%2Fstock_investing-VnnxBpBf%2Flib%2Fpython3.8%2Fsite-packages%2Fmatplotlib%2Fpyplot.py%22%2C%22scheme%22%3A%22file%22%7D%2C%7B%22line%22%3A0%2C%22character%22%3A0%7D%5D "../../../../.local/share/virtualenvs/stock_investing-VnnxBpBf/lib/python3.8/site-packages/matplotlib/pyplot.py").
#
# After the function definition, a random seed is set using [`np.random.seed(1)`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22path%22%3A%22%2Fhome%2Fhung%2F.local%2Fshare%2Fvirtualenvs%2Fstock_investing-VnnxBpBf%2Flib%2Fpython3.8%2Fsite-packages%2Fnumpy%2F__init__.py%22%2C%22scheme%22%3A%22file%22%7D%2C%7B%22line%22%3A0%2C%22character%22%3A0%7D%5D "../../../../.local/share/virtualenvs/stock_investing-VnnxBpBf/lib/python3.8/site-packages/numpy/__init__.py") to ensure reproducibility of the results. Then, a set of 1000 data points is generated using a beta distribution with parameters 5 and 11 using [`stats.beta.rvs(5, 11, size=1000)`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22path%22%3A%22%2Fhome%2Fhung%2F.local%2Fshare%2Fvirtualenvs%2Fstock_investing-VnnxBpBf%2Flib%2Fpython3.8%2Fsite-packages%2Fscipy%2Fstats%2F__init__.py%22%2C%22scheme%22%3A%22file%22%7D%2C%7B%22line%22%3A0%2C%22character%22%3A0%7D%5D "../../../../.local/share/virtualenvs/stock_investing-VnnxBpBf/lib/python3.8/site-packages/scipy/stats/__init__.py"). This data is passed to the [`naive_hpd`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22fsPath%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22path%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22scheme%22%3A%22vscode-notebook-cell%22%2C%22fragment%22%3A%22W6sZmlsZQ%3D%3D%22%7D%2C%7B%22line%22%3A0%2C%22character%22%3A4%7D%5D "/home/hung/Documents/make_color/AI/bayesian_analysis_with_python/1ed/Chapter 1/sample.ipynb") function to generate the plot.
#
# The x-axis limits of the plot are set to 0 and 1 using [`plt.xlim(0, 1)`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22path%22%3A%22%2Fhome%2Fhung%2F.local%2Fshare%2Fvirtualenvs%2Fstock_investing-VnnxBpBf%2Flib%2Fpython3.8%2Fsite-packages%2Fmatplotlib%2Fpyplot.py%22%2C%22scheme%22%3A%22file%22%7D%2C%7B%22line%22%3A0%2C%22character%22%3A0%7D%5D "../../../../.local/share/virtualenvs/stock_investing-VnnxBpBf/lib/python3.8/site-packages/matplotlib/pyplot.py"), and the plot is displayed using [`plt.show()`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22path%22%3A%22%2Fhome%2Fhung%2F.local%2Fshare%2Fvirtualenvs%2Fstock_investing-VnnxBpBf%2Flib%2Fpython3.8%2Fsite-packages%2Fmatplotlib%2Fpyplot.py%22%2C%22scheme%22%3A%22file%22%7D%2C%7B%22line%22%3A0%2C%22character%22%3A0%7D%5D "../../../../.local/share/virtualenvs/stock_investing-VnnxBpBf/lib/python3.8/site-packages/matplotlib/pyplot.py"). The commented out line [`# plt.savefig('B04958_01_07.png', dpi=300, figsize=(5.5, 5.5))`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22path%22%3A%22%2Fhome%2Fhung%2F.local%2Fshare%2Fvirtualenvs%2Fstock_investing-VnnxBpBf%2Flib%2Fpython3.8%2Fsite-packages%2Fmatplotlib%2Fpyplot.py%22%2C%22scheme%22%3A%22file%22%7D%2C%7B%22line%22%3A0%2C%22character%22%3A0%7D%5D "../../../../.local/share/virtualenvs/stock_investing-VnnxBpBf/lib/python3.8/site-packages/matplotlib/pyplot.py") can be used to save the plot as a PNG file with a specified resolution and size.

# %%
np.random.seed(1)    
gauss_a = stats.norm.rvs(loc=4, scale=0.9, size=3000)
gauss_b = stats.norm.rvs(loc=-2, scale=1, size=2000)
mix_norm = np.concatenate((gauss_a, gauss_b))

naive_hpd(mix_norm)
plt.show()
# plt.savefig('B04958_01_08.png', dpi=300, figsize=(5.5, 5.5))

# %% [markdown]
# This Python code is using the `numpy` and `scipy.stats` libraries to generate and manipulate random data, and the `matplotlib.pyplot` and `seaborn` libraries to visualize the data.
#
# The [`np.random.seed(1)`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22path%22%3A%22%2Fhome%2Fhung%2F.local%2Fshare%2Fvirtualenvs%2Fstock_investing-VnnxBpBf%2Flib%2Fpython3.8%2Fsite-packages%2Fnumpy%2F__init__.py%22%2C%22scheme%22%3A%22file%22%7D%2C%7B%22line%22%3A0%2C%22character%22%3A0%7D%5D "../../../../.local/share/virtualenvs/stock_investing-VnnxBpBf/lib/python3.8/site-packages/numpy/__init__.py") line is setting the seed for the random number generator to 1. This ensures that the random numbers generated by the code will be the same each time the code is run, which can be useful for debugging and reproducibility.
#
# Next, [`gauss_a = stats.norm.rvs(loc=4, scale=0.9, size=3000)`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22fsPath%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22path%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22scheme%22%3A%22vscode-notebook-cell%22%2C%22fragment%22%3A%22X10sZmlsZQ%3D%3D%22%7D%2C%7B%22line%22%3A1%2C%22character%22%3A0%7D%5D "/home/hung/Documents/make_color/AI/bayesian_analysis_with_python/1ed/Chapter 1/sample.ipynb") and [`gauss_b = stats.norm.rvs(loc=-2, scale=1, size=2000)`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22fsPath%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22path%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22scheme%22%3A%22vscode-notebook-cell%22%2C%22fragment%22%3A%22X10sZmlsZQ%3D%3D%22%7D%2C%7B%22line%22%3A2%2C%22character%22%3A0%7D%5D "/home/hung/Documents/make_color/AI/bayesian_analysis_with_python/1ed/Chapter 1/sample.ipynb") are generating two sets of random numbers from Gaussian (normal) distributions. The `loc` parameter specifies the mean of the distribution, `scale` specifies the standard deviation, and `size` specifies how many numbers to generate. [`gauss_a`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22fsPath%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22path%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22scheme%22%3A%22vscode-notebook-cell%22%2C%22fragment%22%3A%22X10sZmlsZQ%3D%3D%22%7D%2C%7B%22line%22%3A1%2C%22character%22%3A0%7D%5D "/home/hung/Documents/make_color/AI/bayesian_analysis_with_python/1ed/Chapter 1/sample.ipynb") will contain 3000 numbers with a mean of 4 and a standard deviation of 0.9, while [`gauss_b`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22fsPath%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22path%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22scheme%22%3A%22vscode-notebook-cell%22%2C%22fragment%22%3A%22X10sZmlsZQ%3D%3D%22%7D%2C%7B%22line%22%3A2%2C%22character%22%3A0%7D%5D "/home/hung/Documents/make_color/AI/bayesian_analysis_with_python/1ed/Chapter 1/sample.ipynb") will contain 2000 numbers with a mean of -2 and a standard deviation of 1.
#
# [`mix_norm = np.concatenate((gauss_a, gauss_b))`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22fsPath%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22path%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22scheme%22%3A%22vscode-notebook-cell%22%2C%22fragment%22%3A%22X10sZmlsZQ%3D%3D%22%7D%2C%7B%22line%22%3A3%2C%22character%22%3A0%7D%5D "/home/hung/Documents/make_color/AI/bayesian_analysis_with_python/1ed/Chapter 1/sample.ipynb") is then combining the two sets of numbers into a single array. This is done using `numpy`'s [`concatenate`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22path%22%3A%22%2Fhome%2Fhung%2F.local%2Fshare%2Fvirtualenvs%2Fstock_investing-VnnxBpBf%2Flib%2Fpython3.8%2Fsite-packages%2Fnumpy%2Fcore%2Fmultiarray.py%22%2C%22scheme%22%3A%22file%22%7D%2C%7B%22line%22%3A152%2C%22character%22%3A4%7D%5D "../../../../.local/share/virtualenvs/stock_investing-VnnxBpBf/lib/python3.8/site-packages/numpy/core/multiarray.py") function, which takes a tuple of arrays and joins them along an existing axis.
#
# The [`naive_hpd(mix_norm)`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22fsPath%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22path%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22scheme%22%3A%22vscode-notebook-cell%22%2C%22fragment%22%3A%22W6sZmlsZQ%3D%3D%22%7D%2C%7B%22line%22%3A0%2C%22character%22%3A4%7D%5D "/home/hung/Documents/make_color/AI/bayesian_analysis_with_python/1ed/Chapter 1/sample.ipynb") line is calling a function named [`naive_hpd`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22fsPath%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22path%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22scheme%22%3A%22vscode-notebook-cell%22%2C%22fragment%22%3A%22W6sZmlsZQ%3D%3D%22%7D%2C%7B%22line%22%3A0%2C%22character%22%3A4%7D%5D "/home/hung/Documents/make_color/AI/bayesian_analysis_with_python/1ed/Chapter 1/sample.ipynb") on the combined data. This function is not defined in the provided code, but based on the provided function implementation, it appears to create a kernel density estimate plot of the data using `seaborn`'s `kdeplot` function, mark the highest posterior density (HPD) interval on the plot, and then remove the y-axis ticks.
#
# Finally, [`plt.show()`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22path%22%3A%22%2Fhome%2Fhung%2F.local%2Fshare%2Fvirtualenvs%2Fstock_investing-VnnxBpBf%2Flib%2Fpython3.8%2Fsite-packages%2Fmatplotlib%2Fpyplot.py%22%2C%22scheme%22%3A%22file%22%7D%2C%7B%22line%22%3A0%2C%22character%22%3A0%7D%5D "../../../../.local/share/virtualenvs/stock_investing-VnnxBpBf/lib/python3.8/site-packages/matplotlib/pyplot.py") is used to display the plot. The line [`# plt.savefig('B04958_01_08.png', dpi=300, figsize=(5.5, 5.5))`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22path%22%3A%22%2Fhome%2Fhung%2F.local%2Fshare%2Fvirtualenvs%2Fstock_investing-VnnxBpBf%2Flib%2Fpython3.8%2Fsite-packages%2Fmatplotlib%2Fpyplot.py%22%2C%22scheme%22%3A%22file%22%7D%2C%7B%22line%22%3A0%2C%22character%22%3A0%7D%5D "../../../../.local/share/virtualenvs/stock_investing-VnnxBpBf/lib/python3.8/site-packages/matplotlib/pyplot.py") is commented out, but if it were uncommented, it would save the plot as a PNG file with a resolution of 300 dots per inch and a size of 5.5 by 5.5 inches.

# %%
from plot_post import plot_post
plot_post(mix_norm, roundto=2, alpha=0.05)
plt.legend(loc=0, fontsize=16)
plt.xlabel(r"$\theta$", fontsize=14)
plt.show()
# plt.savefig('B04958_01_09.png', dpi=300, figsize=(5.5, 5.5))

# %% [markdown]
# This Python code snippet is used for visualizing the posterior distribution of a Bayesian analysis. It uses the [`plot_post`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22path%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fplot_post.py%22%2C%22scheme%22%3A%22file%22%7D%2C%7B%22line%22%3A7%2C%22character%22%3A4%7D%5D "1ed/Chapter 1/plot_post.py") function from the [`plot_post`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22path%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fplot_post.py%22%2C%22scheme%22%3A%22file%22%7D%2C%7B%22line%22%3A7%2C%22character%22%3A4%7D%5D "1ed/Chapter 1/plot_post.py") module to create the plot, and matplotlib's pyplot (imported as [`plt`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22path%22%3A%22%2Fhome%2Fhung%2F.local%2Fshare%2Fvirtualenvs%2Fstock_investing-VnnxBpBf%2Flib%2Fpython3.8%2Fsite-packages%2Fmatplotlib%2Fpyplot.py%22%2C%22scheme%22%3A%22file%22%7D%2C%7B%22line%22%3A0%2C%22character%22%3A0%7D%5D "../../../../.local/share/virtualenvs/stock_investing-VnnxBpBf/lib/python3.8/site-packages/matplotlib/pyplot.py")) to customize and display the plot.
#
# The [`plot_post`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22path%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fplot_post.py%22%2C%22scheme%22%3A%22file%22%7D%2C%7B%22line%22%3A7%2C%22character%22%3A4%7D%5D "1ed/Chapter 1/plot_post.py") function is called with three arguments: [`mix_norm`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22fsPath%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22path%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22scheme%22%3A%22vscode-notebook-cell%22%2C%22fragment%22%3A%22X10sZmlsZQ%3D%3D%22%7D%2C%7B%22line%22%3A3%2C%22character%22%3A0%7D%5D "/home/hung/Documents/make_color/AI/bayesian_analysis_with_python/1ed/Chapter 1/sample.ipynb"), [`roundto=2`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22path%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fplot_post.py%22%2C%22scheme%22%3A%22file%22%7D%2C%7B%22line%22%3A8%2C%22character%22%3A30%7D%5D "1ed/Chapter 1/plot_post.py"), and [`alpha=0.05`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22path%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fplot_post.py%22%2C%22scheme%22%3A%22file%22%7D%2C%7B%22line%22%3A7%2C%22character%22%3A22%7D%5D "1ed/Chapter 1/plot_post.py"). [`mix_norm`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22fsPath%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22path%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fsample.ipynb%22%2C%22scheme%22%3A%22vscode-notebook-cell%22%2C%22fragment%22%3A%22X10sZmlsZQ%3D%3D%22%7D%2C%7B%22line%22%3A3%2C%22character%22%3A0%7D%5D "/home/hung/Documents/make_color/AI/bayesian_analysis_with_python/1ed/Chapter 1/sample.ipynb") is likely a sample from the posterior distribution that you want to visualize. The [`roundto`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22path%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fplot_post.py%22%2C%22scheme%22%3A%22file%22%7D%2C%7B%22line%22%3A8%2C%22character%22%3A30%7D%5D "1ed/Chapter 1/plot_post.py") argument specifies the number of decimal places to which numerical results should be rounded, and [`alpha`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22path%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fplot_post.py%22%2C%22scheme%22%3A%22file%22%7D%2C%7B%22line%22%3A7%2C%22character%22%3A22%7D%5D "1ed/Chapter 1/plot_post.py") is the desired probability of type I error (defaults to 0.05).
#
# After the [`plot_post`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22path%22%3A%22%2Fhome%2Fhung%2FDocuments%2Fmake_color%2FAI%2Fbayesian_analysis_with_python%2F1ed%2FChapter%201%2Fplot_post.py%22%2C%22scheme%22%3A%22file%22%7D%2C%7B%22line%22%3A7%2C%22character%22%3A4%7D%5D "1ed/Chapter 1/plot_post.py") function is called, [`plt.legend(loc=0, fontsize=16)`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22path%22%3A%22%2Fhome%2Fhung%2F.local%2Fshare%2Fvirtualenvs%2Fstock_investing-VnnxBpBf%2Flib%2Fpython3.8%2Fsite-packages%2Fmatplotlib%2Fpyplot.py%22%2C%22scheme%22%3A%22file%22%7D%2C%7B%22line%22%3A0%2C%22character%22%3A0%7D%5D "../../../../.local/share/virtualenvs/stock_investing-VnnxBpBf/lib/python3.8/site-packages/matplotlib/pyplot.py") is used to add a legend to the plot. The `loc=0` argument means that the best location for the legend will be determined automatically, and `fontsize=16` sets the font size of the legend's text.
#
# Next, [`plt.xlabel(r"$\theta$", fontsize=14)`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22path%22%3A%22%2Fhome%2Fhung%2F.local%2Fshare%2Fvirtualenvs%2Fstock_investing-VnnxBpBf%2Flib%2Fpython3.8%2Fsite-packages%2Fmatplotlib%2Fpyplot.py%22%2C%22scheme%22%3A%22file%22%7D%2C%7B%22line%22%3A0%2C%22character%22%3A0%7D%5D "../../../../.local/share/virtualenvs/stock_investing-VnnxBpBf/lib/python3.8/site-packages/matplotlib/pyplot.py") is used to set the label for the x-axis to the Greek letter theta (θ), and the font size of the label is set to 14.
#
# Finally, [`plt.show()`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22path%22%3A%22%2Fhome%2Fhung%2F.local%2Fshare%2Fvirtualenvs%2Fstock_investing-VnnxBpBf%2Flib%2Fpython3.8%2Fsite-packages%2Fmatplotlib%2Fpyplot.py%22%2C%22scheme%22%3A%22file%22%7D%2C%7B%22line%22%3A0%2C%22character%22%3A0%7D%5D "../../../../.local/share/virtualenvs/stock_investing-VnnxBpBf/lib/python3.8/site-packages/matplotlib/pyplot.py") is called to display the plot. There's also a commented out line of code [`# plt.savefig('B04958_01_09.png', dpi=300, figsize=(5.5, 5.5))`](command:_github.copilot.openSymbolFromReferences?%5B%7B%22%24mid%22%3A1%2C%22path%22%3A%22%2Fhome%2Fhung%2F.local%2Fshare%2Fvirtualenvs%2Fstock_investing-VnnxBpBf%2Flib%2Fpython3.8%2Fsite-packages%2Fmatplotlib%2Fpyplot.py%22%2C%22scheme%22%3A%22file%22%7D%2C%7B%22line%22%3A0%2C%22character%22%3A0%7D%5D "../../../../.local/share/virtualenvs/stock_investing-VnnxBpBf/lib/python3.8/site-packages/matplotlib/pyplot.py") which, if uncommented, would save the plot as a PNG image file with a resolution of 300 dots per inch and a size of 5.5 by 5.5 inches.
